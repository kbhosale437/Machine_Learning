# %%
import pandas as pd

# %%
Bhousing=pd.read_csv("/Users/karanbhosale/Documents/Big Data Strategy/Bhousing(1).csv")

# %%
Bhousing.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.5
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2
# ...

# %%
import statsmodels.api as sm

# %%
model=sm.OLS(Bhousing.MEDV,Bhousing.RM)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.901
# Model:                            OLS   Adj. R-squared (uncentered):              0.901
# Method:                 Least Squares   F-statistic:                              4614.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   3.77e-256
# Time:                        14:12:41   Log-Likelihood:                         -1747.1
# No. Observations:                 506   AIC:                                      3496.
# Df Residuals:                     505   BIC:                                      3500.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Bhousing.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
model=sm.OLS(Bhousing.MEDV,Bhousing.INDUS)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.480
# Model:                            OLS   Adj. R-squared (uncentered):              0.479
# Method:                 Least Squares   F-statistic:                              466.3
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                    9.55e-74
# Time:                        14:30:15   Log-Likelihood:                         -2167.6
# No. Observations:                 506   AIC:                                      4337.
# Df Residuals:                     505   BIC:                                      4341.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model=sm.OLS(Bhousing.MEDV,Bhousing.NOX)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.763
# Model:                            OLS   Adj. R-squared (uncentered):              0.763
# Method:                 Least Squares   F-statistic:                              1626.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   5.54e-160
# Time:                        14:31:03   Log-Likelihood:                         -1968.9
# No. Observations:                 506   AIC:                                      3940.
# Df Residuals:                     505   BIC:                                      3944.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model=sm.OLS(Bhousing.MEDV,Bhousing.AGE)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.644
# Model:                            OLS   Adj. R-squared (uncentered):              0.644
# Method:                 Least Squares   F-statistic:                              915.1
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   1.85e-115
# Time:                        14:31:10   Log-Likelihood:                         -2071.5
# No. Observations:                 506   AIC:                                      4145.
# Df Residuals:                     505   BIC:                                      4149.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model=sm.OLS(Bhousing.MEDV,Bhousing.DIS)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.732
# Model:                            OLS   Adj. R-squared (uncentered):              0.732
# Method:                 Least Squares   F-statistic:                              1380.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   1.52e-146
# Time:                        14:31:22   Log-Likelihood:                         -1999.8
# No. Observations:                 506   AIC:                                      4002.
# Df Residuals:                     505   BIC:                                      4006.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model=sm.OLS(Bhousing.MEDV,Bhousing.RAD)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.345
# Model:                            OLS   Adj. R-squared (uncentered):              0.344
# Method:                 Least Squares   F-statistic:                              266.2
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                    2.24e-48
# Time:                        14:31:28   Log-Likelihood:                         -2226.0
# No. Observations:                 506   AIC:                                      4454.
# Df Residuals:                     505   BIC:                                      4458.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model=sm.OLS(Bhousing.MEDV,Bhousing.TAX)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.622
# Model:                            OLS   Adj. R-squared (uncentered):              0.621
# Method:                 Least Squares   F-statistic:                              830.5
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   1.02e-108
# Time:                        14:31:33   Log-Likelihood:                         -2087.0
# No. Observations:                 506   AIC:                                      4176.
# Df Residuals:                     505   BIC:                                      4180.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model=sm.OLS(Bhousing.MEDV,Bhousing.PTRATIO)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.708
# Model:                            OLS   Adj. R-squared (uncentered):              0.706
# Method:                 Least Squares   F-statistic:                              304.4
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   1.06e-132
# Time:                        14:40:32   Log-Likelihood:                         -2021.5
# No. Observations:                 506   AIC:                                      4051.
# Df Residuals:                     502   BIC:                                      4068.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model=sm.OLS(Bhousing.MEDV,Bhousing.LSTAT)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.449
# Model:                            OLS   Adj. R-squared (uncentered):              0.448
# Method:                 Least Squares   F-statistic:                              410.9
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                    2.71e-67
# Time:                        14:32:07   Log-Likelihood:                         -2182.4
# No. Observations:                 506   AIC:                                      4367.
# Df Residuals:                     505   BIC:                                      4371.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Y=Bhousing.MEDV
X=Bhousing[['CRIM','ZN','INDUS','CHAS']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.708
# Model:                            OLS   Adj. R-squared (uncentered):              0.706
# Method:                 Least Squares   F-statistic:                              304.4
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   1.06e-132
# Time:                        14:41:00   Log-Likelihood:                         -2021.5
# No. Observations:                 506   AIC:                                      4051.
# Df Residuals:                     502   BIC:                                      4068.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Y=Bhousing.MEDV
X=Bhousing[['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','LSTAT']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.957
# Model:                            OLS   Adj. R-squared (uncentered):              0.956
# Method:                 Least Squares   F-statistic:                              908.6
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        14:48:09   Log-Likelihood:                         -1539.0
# No. Observations:                 506   AIC:                                      3102.
# Df Residuals:                     494   BIC:                                      3153.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Y=Bhousing.MEDV
X=Bhousing[['CRIM','ZN','INDUS','CHAS','RM','AGE','DIS','RAD','TAX','PTRATIO','LSTAT']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.957
# Model:                            OLS   Adj. R-squared (uncentered):              0.956
# Method:                 Least Squares   F-statistic:                              993.1
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        14:54:52   Log-Likelihood:                         -1539.0
# No. Observations:                 506   AIC:                                      3100.
# Df Residuals:                     495   BIC:                                      3147.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Y=Bhousing.MEDV
X=Bhousing[['CRIM','ZN','INDUS','CHAS','NOX','RM','DIS','RAD','TAX','PTRATIO','LSTAT']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.957
# Model:                            OLS   Adj. R-squared (uncentered):              0.956
# Method:                 Least Squares   F-statistic:                              993.1
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        14:55:47   Log-Likelihood:                         -1539.0
# No. Observations:                 506   AIC:                                      3100.
# Df Residuals:                     495   BIC:                                      3147.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Y=Bhousing.MEDV
X=Bhousing[['CRIM','ZN','CHAS','RM','DIS','RAD','TAX','PTRATIO','LSTAT']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.957
# Model:                            OLS   Adj. R-squared (uncentered):              0.956
# Method:                 Least Squares   F-statistic:                              1218.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        14:56:37   Log-Likelihood:                         -1539.2
# No. Observations:                 506   AIC:                                      3096.
# Df Residuals:                     497   BIC:                                      3134.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
BH=Bhousing.corr()
BH
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables=result.model.exog
vif=[variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
vif
# Out:
# [2.068558642102146,
#  2.7399841334230484,
#  1.1191151563881154,
#  44.774278129179166,
#  10.702550982236668,
#  13.326823967608716,
#  43.5878665399207,
#  77.1273951132758,
#  7.788457599440839]

# %%
Y=Bhousing.MEDV
X=Bhousing[['CRIM','ZN','CHAS','RM','DIS','RAD','TAX','LSTAT']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.956
# Model:                            OLS   Adj. R-squared (uncentered):              0.955
# Method:                 Least Squares   F-statistic:                              1359.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        15:13:44   Log-Likelihood:                         -1541.7
# No. Observations:                 506   AIC:                                      3099.
# Df Residuals:                     498   BIC:                                      3133.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables=result.model.exog
vif=[variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
vif
# Out:
# [2.0680914538205637,
#  2.2617168531738616,
#  1.1147500073522616,
#  19.407593308685094,
#  8.462495483998756,
#  13.259635273553883,
#  39.39833607667787,
#  6.474431234813925]

# %%
Y=Bhousing.MEDV
X=Bhousing[['CRIM','ZN','CHAS','RM','DIS','RAD','LSTAT']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.955
# Model:                            OLS   Adj. R-squared (uncentered):              0.954
# Method:                 Least Squares   F-statistic:                              1507.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                        0.00
# Time:                        15:14:11   Log-Likelihood:                         -1549.5
# No. Observations:                 506   AIC:                                      3113.
# Df Residuals:                     499   BIC:                                      3143.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables=result.model.exog
vif=[variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
vif
# Out:
# [2.062182766214216,
#  2.254764072883299,
#  1.1093747819871924,
#  11.760252351938535,
#  8.421838778469064,
#  4.298664785507667,
#  5.149899422528694]

# %%
Y=Bhousing.MEDV
X=Bhousing[['CRIM','ZN','CHAS','DIS','RAD','LSTAT']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.793
# Model:                            OLS   Adj. R-squared (uncentered):              0.790
# Method:                 Least Squares   F-statistic:                              319.1
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   2.17e-167
# Time:                        15:14:44   Log-Likelihood:                         -1934.7
# No. Observations:                 506   AIC:                                      3881.
# Df Residuals:                     500   BIC:                                      3907.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables=result.model.exog
vif=[variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
vif
# Out:
# [2.0405218396990117,
#  2.2375337533434205,
#  1.059249264395732,
#  3.941628732421162,
#  3.738091484464664,
#  4.2485126843488015]

# %%
import numpy as np

# %%
Bhousing['Log_CRIM']=np.log(Bhousing.CRIM)
Bhousing['Log_MEDV']=np.log(Bhousing.MEDV)

# %%
Y=Bhousing.Log_MEDV
X=Bhousing[['Log_CRIM','ZN','CHAS','DIS','RAD','LSTAT']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:               Log_MEDV   R-squared (uncentered):                   0.929
# Model:                            OLS   Adj. R-squared (uncentered):              0.928
# Method:                 Least Squares   F-statistic:                              1082.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   1.00e-282
# Time:                        15:29:35   Log-Likelihood:                         -616.75
# No. Observations:                 506   AIC:                                      1246.
# Df Residuals:                     500   BIC:                                      1271.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Wine=pd.read_csv("/Users/karanbhosale/Documents/Big Data Strategy/Wine.csv")

# %%
Y=Wine.Class
X=Wine[["Alcohol",'Malic_acid','Ash']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.880
# Model:                            OLS   Adj. R-squared (uncentered):              0.878
# Method:                 Least Squares   F-statistic:                              426.0
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                    3.66e-80
# Time:                        15:49:08   Log-Likelihood:                         -195.12
# No. Observations:                 178   AIC:                                      396.2
# Df Residuals:                     175   BIC:                                      405.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
Wine.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic_acid', 'Ash', 'Alcalinity_Ash', 'Magnesium',
#        'Total_phenols', 'Flavanoids', 'Noflavanoid_phenols', 'Proanthocyanins',
#        'Color_intensity', 'Hue', 'OD280', 'Proline'],
#       dtype='object')

# %%
Y=Wine.Class
X=Wine[["Alcohol",'Malic_acid','Ash','Alcalinity_Ash','Magnesium','Total_phenols','Flavanoids',
       'Noflavanoid_phenols','Proanthocyanins','Color_intensity','Hue','OD280','Proline']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.980
# Model:                            OLS   Adj. R-squared (uncentered):              0.978
# Method:                 Least Squares   F-statistic:                              607.6
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   5.95e-132
# Time:                        15:51:20   Log-Likelihood:                         -37.353
# No. Observations:                 178   AIC:                                      100.7
# Df Residuals:                     165   BIC:                                      142.1
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
Y=Wine.Class
X=Wine[["Alcohol",'Alcalinity_Ash','Total_phenols','Flavanoids',
       'Color_intensity','OD280','Proline']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.979
# Model:                            OLS   Adj. R-squared (uncentered):              0.978
# Method:                 Least Squares   F-statistic:                              1116.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   3.92e-139
# Time:                        15:53:31   Log-Likelihood:                         -41.433
# No. Observations:                 178   AIC:                                      96.87
# Df Residuals:                     171   BIC:                                      119.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables=result.model.exog
vif=[variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
vif
# Out:
# [110.4488570965163,
#  37.403470673120076,
#  61.42995916757194,
#  28.652206775327716,
#  11.981931528225042,
#  52.443001875730566,
#  14.487416145895514]

# %%
Y=Wine.Class
X=Wine[['Alcalinity_Ash','Flavanoids',
       'Color_intensity']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Class   R-squared (uncentered):                   0.961
# Model:                            OLS   Adj. R-squared (uncentered):              0.960
# Method:                 Least Squares   F-statistic:                              1427.
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):                   9.81e-123
# Time:                        15:57:56   Log-Likelihood:                         -95.366
# No. Observations:                 178   AIC:                                      196.7
# Df Residuals:                     175   BIC:                                      206.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables=result.model.exog
vif=[variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
vif
# Out:
# [7.573447485489634, 3.82454323169002, 5.176870672169302]

# %%
Cars=pd.read_csv("/Users/karanbhosale/Documents/Big Data Strategy/Car.csv")

# %%
Cars.columns
# Out:
# Index(['Id', 'Model', 'Price', 'Mfg_Year', 'KM', 'Fuel_Type', 'HP',
#        'Met_Color', 'Color', 'Automatic', 'CC', 'Doors', 'Cylinders', 'Gears',
#        'Quarterly_Tax', 'Weight', 'Mfr_Guarantee', 'BOVAG_Guarantee',
#        'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2', 'Airco',
#        'Automatic_airco', 'Boardcomputer', 'CD_Player', 'Central_Lock',
#        'Powered_Windows', 'Power_Steering', 'Radio', 'Mistlamps',
#        'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
#        'Parking_Assistant', 'Tow_Bar'],
#       dtype='object')

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP','Met_Color', 'Automatic', 
        'CC', 'Doors', 'Cylinders', 'Gears','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player', 'Central_Lock',
       'Powered_Windows', 'Power_Steering', 'Radio', 'Mistlamps',
       'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
       'Parking_Assistant', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     434.8
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:08:27   Log-Likelihood:                -12112.
# No. Observations:                1436   AIC:                         2.429e+04
# Df Residuals:                    1404   BIC:                         2.446e+04
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
        'CC', 'Doors', 'Cylinders', 'Gears','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player', 'Central_Lock',
       'Powered_Windows', 'Power_Steering', 'Radio', 'Mistlamps',
       'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
       'Parking_Assistant', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     449.6
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:08:56   Log-Likelihood:                -12112.
# No. Observations:                1436   AIC:                         2.429e+04
# Df Residuals:                    1405   BIC:                         2.445e+04
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
        'CC', 'Doors', 'Cylinders', 'Gears','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player', 'Central_Lock',
       'Powered_Windows', 'Power_Steering', 'Radio', 'Mistlamps',
       'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
       'Parking_Assistant', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     449.6
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:09:48   Log-Likelihood:                -12112.
# No. Observations:                1436   AIC:                         2.429e+04
# Df Residuals:                    1405   BIC:                         2.445e+04
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
        'CC', 'Doors', 'Cylinders', 'Gears','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player', 'Central_Lock',
       'Powered_Windows', 'Power_Steering', 'Radio',
       'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
       'Parking_Assistant', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     465.3
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:10:18   Log-Likelihood:                -12112.
# No. Observations:                1436   AIC:                         2.428e+04
# Df Residuals:                    1406   BIC:                         2.444e+04
# Df Model:                          29
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
        'CC', 'Doors', 'Cylinders', 'Gears','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airbag_1', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player', 'Central_Lock',
       'Powered_Windows', 'Power_Steering', 'Radio',
       'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
       'Parking_Assistant', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     482.2
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:10:51   Log-Likelihood:                -12112.
# No. Observations:                1436   AIC:                         2.428e+04
# Df Residuals:                    1407   BIC:                         2.443e+04
# Df Model:                          28
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
        'CC', 'Doors', 'Cylinders', 'Gears','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airbag_1', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player',
       'Powered_Windows', 'Power_Steering', 'Radio',
       'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
       'Parking_Assistant', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     500.2
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:11:35   Log-Likelihood:                -12112.
# No. Observations:                1436   AIC:                         2.428e+04
# Df Residuals:                    1408   BIC:                         2.443e+04
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
        'CC', 'Doors', 'Cylinders', 'Gears','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airbag_1', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player',
       'Powered_Windows', 'Power_Steering',
       'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
       'Parking_Assistant', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     519.5
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:12:29   Log-Likelihood:                -12113.
# No. Observations:                1436   AIC:                         2.428e+04
# Df Residuals:                    1409   BIC:                         2.442e+04
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
        'CC', 'Doors', 'Cylinders', 'Gears','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airbag_1', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player',
       'Powered_Windows',
       'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
       'Parking_Assistant', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     540.1
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:13:17   Log-Likelihood:                -12113.
# No. Observations:                1436   AIC:                         2.428e+04
# Df Residuals:                    1410   BIC:                         2.442e+04
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
        'CC', 'Doors', 'Cylinders', 'Gears','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player',
       'Powered_Windows',
       'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
       'Parking_Assistant', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     562.8
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:14:19   Log-Likelihood:                -12114.
# No. Observations:                1436   AIC:                         2.428e+04
# Df Residuals:                    1411   BIC:                         2.441e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
        'CC', 'Doors', 'Cylinders', 'Gears','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player',
       'Powered_Windows',
       'Sport_Model', 'Backseat_Divider', 'Metallic_Rim',
       'Parking_Assistant', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     587.4
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:14:44   Log-Likelihood:                -12114.
# No. Observations:                1436   AIC:                         2.428e+04
# Df Residuals:                    1412   BIC:                         2.440e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
        'CC', 'Doors', 'Cylinders', 'Gears','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player',
       'Powered_Windows',
       'Sport_Model', 'Metallic_Rim',
       'Parking_Assistant', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     613.9
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:15:12   Log-Likelihood:                -12115.
# No. Observations:                1436   AIC:                         2.428e+04
# Df Residuals:                    1413   BIC:                         2.440e+04
# Df Model:                          22
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
        'CC', 'Doors', 'Cylinders','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player',
       'Powered_Windows',
       'Sport_Model', 'Metallic_Rim',
       'Parking_Assistant', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     642.9
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:15:42   Log-Likelihood:                -12115.
# No. Observations:                1436   AIC:                         2.427e+04
# Df Residuals:                    1414   BIC:                         2.439e+04
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
        'CC', 'Doors', 'Cylinders', 'Gears','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player',
       'Powered_Windows',
       'Sport_Model', 'Metallic_Rim', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     642.4
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:16:25   Log-Likelihood:                -12116.
# No. Observations:                1436   AIC:                         2.428e+04
# Df Residuals:                    1414   BIC:                         2.439e+04
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
        'CC', 'Doors', 'Cylinders','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player',
       'Powered_Windows',
       'Sport_Model', 'Metallic_Rim', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     674.3
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:16:45   Log-Likelihood:                -12116.
# No. Observations:                1436   AIC:                         2.427e+04
# Df Residuals:                    1415   BIC:                         2.439e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
        'Doors', 'Cylinders','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player',
       'Powered_Windows',
       'Sport_Model', 'Metallic_Rim', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     709.1
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:19:07   Log-Likelihood:                -12118.
# No. Observations:                1436   AIC:                         2.428e+04
# Df Residuals:                    1416   BIC:                         2.438e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
     'Cylinders','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player',
       'Powered_Windows',
       'Sport_Model', 'Metallic_Rim', 'Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     746.6
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:19:31   Log-Likelihood:                -12120.
# No. Observations:                1436   AIC:                         2.428e+04
# Df Residuals:                    1417   BIC:                         2.438e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
     'Cylinders','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airco',
       'Automatic_airco', 'Boardcomputer', 'CD_Player',
       'Powered_Windows',
       'Sport_Model','Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     788.2
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:19:54   Log-Likelihood:                -12122.
# No. Observations:                1436   AIC:                         2.428e+04
# Df Residuals:                    1418   BIC:                         2.437e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
     'Cylinders','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airco',
       'Automatic_airco', 'Boardcomputer',
       'Powered_Windows',
       'Sport_Model','Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     834.4
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:20:19   Log-Likelihood:                -12125.
# No. Observations:                1436   AIC:                         2.428e+04
# Df Residuals:                    1419   BIC:                         2.437e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 'Automatic', 
     'Cylinders','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airco',
       'Automatic_airco',
       'Powered_Windows',
       'Sport_Model','Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.902
# Method:                 Least Squares   F-statistic:                     886.2
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:20:45   Log-Likelihood:                -12128.
# No. Observations:                1436   AIC:                         2.429e+04
# Df Residuals:                    1420   BIC:                         2.437e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
Y=Cars.Price
X=Cars[['Mfg_Year','KM','HP', 
     'Cylinders','Quarterly_Tax', 'Weight', 
        'Mfr_Guarantee', 'BOVAG_Guarantee',
       'Guarantee_Period', 'ABS', 'Airco',
       'Automatic_airco',
       'Powered_Windows',
       'Sport_Model','Tow_Bar']]
model=sm.OLS(Y,X)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.902
# Method:                 Least Squares   F-statistic:                     945.9
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        16:21:04   Log-Likelihood:                -12131.
# No. Observations:                1436   AIC:                         2.429e+04
# Df Residuals:                    1421   BIC:                         2.437e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
Diabetes=pd.read_csv("/Users/karanbhosale/Documents/Big Data Strategy/Diabetes.csv")

# %%
Diabetes.columns
# Out:
# Index(['pregnancies', 'glucose', 'diatolic', 'triceps', 'insulin', 'bmi',
#        'dpf', 'age', 'test'],
#       dtype='object')

# %%
Y=Diabetes.test
X=Diabetes[['pregnancies', 'glucose', 'diatolic', 'triceps', 'insulin', 'bmi',
       'dpf', 'age']]
model=sm.Logit(Y,X)
result=model.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.608498
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                  768
# Model:                          Logit   Df Residuals:                      760
# Method:                           MLE   Df Model:                            7
# Date:                Thu, 09 Nov 2023   Pseudo R-squ.:                 0.05922
# Time:                        16:29:31   Log-Likelihood:                -467.33
# converged:                       True   LL-Null:                       -496.74
# Covariance Type:            nonrobust   LLR p-value:                 2.583e-10
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
Y=Diabetes.test
X=Diabetes[['pregnancies', 'glucose', 'diatolic', 'insulin', 'bmi',
       'dpf', 'age',]]
model=sm.Logit(Y,X)
result=model.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.608499
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                  768
# Model:                          Logit   Df Residuals:                      761
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 09 Nov 2023   Pseudo R-squ.:                 0.05922
# Time:                        16:29:46   Log-Likelihood:                -467.33
# converged:                       True   LL-Null:                       -496.74
# Covariance Type:            nonrobust   LLR p-value:                 7.777e-11
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
Y=Diabetes.test
X=Diabetes[['pregnancies', 'glucose', 'diatolic', 'insulin',
       'dpf', 'age',]]
model=sm.Logit(Y,X)
result=model.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.608642
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                  768
# Model:                          Logit   Df Residuals:                      762
# Method:                           MLE   Df Model:                            5
# Date:                Thu, 09 Nov 2023   Pseudo R-squ.:                 0.05899
# Time:                        16:30:09   Log-Likelihood:                -467.44
# converged:                       True   LL-Null:                       -496.74
# Covariance Type:            nonrobust   LLR p-value:                 2.354e-11
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
Y=Diabetes.test
X=Diabetes[['pregnancies', 'glucose', 'diatolic',
       'dpf', 'age',]]
model=sm.Logit(Y,X)
result=model.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.609329
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                  768
# Model:                          Logit   Df Residuals:                      763
# Method:                           MLE   Df Model:                            4
# Date:                Thu, 09 Nov 2023   Pseudo R-squ.:                 0.05793
# Time:                        16:30:23   Log-Likelihood:                -467.96
# converged:                       True   LL-Null:                       -496.74
# Covariance Type:            nonrobust   LLR p-value:                 9.466e-12
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
Y=Diabetes.test
X=Diabetes[['pregnancies', 'glucose', 'diatolic', 'insulin',
        'age',]]
model=sm.Logit(Y,X)
result=model.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.609719
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                  768
# Model:                          Logit   Df Residuals:                      763
# Method:                           MLE   Df Model:                            4
# Date:                Thu, 09 Nov 2023   Pseudo R-squ.:                 0.05733
# Time:                        16:30:35   Log-Likelihood:                -468.26
# converged:                       True   LL-Null:                       -496.74
# Covariance Type:            nonrobust   LLR p-value:                 1.264e-11
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
Y=Diabetes.test
X=Diabetes[['pregnancies', 'glucose', 'diatolic', 
        'age',]]
model=sm.Logit(Y,X)
result=model.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.610634
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                  768
# Model:                          Logit   Df Residuals:                      764
# Method:                           MLE   Df Model:                            3
# Date:                Thu, 09 Nov 2023   Pseudo R-squ.:                 0.05591
# Time:                        16:30:48   Log-Likelihood:                -468.97
# converged:                       True   LL-Null:                       -496.74
# Covariance Type:            nonrobust   LLR p-value:                 5.239e-12
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
Y=Diabetes.test
X=Diabetes[['pregnancies', 'glucose', 'diatolic',]]
model=sm.Logit(Y,X)
result=model.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.613118
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   test   No. Observations:                  768
# Model:                          Logit   Df Residuals:                      765
# Method:                           MLE   Df Model:                            2
# Date:                Thu, 09 Nov 2023   Pseudo R-squ.:                 0.05207
# Time:                        16:31:02   Log-Likelihood:                -470.87
# converged:                       True   LL-Null:                       -496.74
# Covariance Type:            nonrobust   LLR p-value:                 5.835e-12
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables=result.model.exog
vif=[variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
vif
# Out:
# [2.37188835416066, 9.155417865821633, 9.168722233458638]
