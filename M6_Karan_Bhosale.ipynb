# %%
import pandas as pd

# %%
Bhousing=pd.read_csv(r"/Users/karanbhosale/Documents/Big Data Strategy/Bhousing.csv")

# %%
Bhousing.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.5
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
Bhousing.tail(5)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#      LSTAT  MEDV
# 501   9.67  22.4
# 502   9.08  20.6
# 503   5.64  23.9
# 504   6.48  22.0
# 505   7.88  11.9

# %%
Bhousing.shape
# Out:
# (506, 13)

# %%
Bhousing.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
Bhousing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
Bhousing.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
Bhousing.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.5
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
Bhousing.iloc[5]["AGE"]
# Out:
# 58.7

# %%
Bhousing.at[5,'AGE']=60.7

# %%
Bhousing.iloc[5]['AGE']
# Out:
# 60.7

# %%
Bhousing2=Bhousing[Bhousing.CRIM>=0.2]

# %%
Bhousing.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   60.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.5
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2
# ...

# %%
Bhousing3=Bhousing[(Bhousing.CRIM>=0.2)&(Bhousing.RM>=5)&(Bhousing.RAD==4)]

# %%
Bhousing3.shape
# Out:
# (55, 13)

# %%
Bhousing3
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 13   0.62976  0.0   8.14     0  0.538  5.949   61.8  4.7075    4  307
# 14   0.63796  0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307
# 15   0.62739  0.0   8.14     0  0.538  5.834   56.5  4.4986    4  307
# 16   1.05393  0.0   8.14     0  0.538  5.935   29.3  4.4986    4  307
# 17   0.78420  0.0   8.14     0  0.538  5.990   81.7  4.2579    4  307
# 18   0.80271  0.0   8.14     0  0.538  5.456   36.6  3.7965    4  307
# 19   0.72580  0.0   8.14     0  0.538  5.727   69.5  3.7965    4  307
# 20   1.25179  0.0   8.14     0  0.538  5.570   98.1  3.7979    4  307
# 21   0.85204  0.0   8.14     0  0.538  5.965   89.2  4.0123    4  307
# 22   1.23247  0.0   8.14     0  0.538  6.142   91.7  3.9769    4  307
# 23   0.98843  0.0   8.14     0  0.538  5.813  100.0  4.0952    4  307
# 24   0.75026  0.0   8.14     0  0.538  5.924   94.1  4.3996    4  307
# ...

# %%
import numpy as np

# %%
Bhousing['Log_AGE']=np.log(Bhousing.AGE)

# %%
Bhousing.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV   Log_AGE
# 0   4.98  24.0  4.177459
# 1   9.14  21.5  4.368181
# 2   4.03  34.7  4.112512
# 3   2.94  33.4  3.824284
# 4   5.33  36.2  3.992681

# %%
del Bhousing['Log_AGE']

# %%
Bhousing.head(6)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430  60.7  6.0622    3  222     18.7
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.5
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2
# 5   5.21  28.7

# %%
Bhousing.rename(columns={'ZN':'ZONE'},inplace=True)

# %%
Bhousing.head(5)
# Out:
#       CRIM  ZONE  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.5
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(Bhousing.AGE)
plt.show()

# %%
plt.hist(Bhousing.AGE,rwidth=0.7,color="black",orientation='horizontal')
plt.xlabel('Average age of house')
plt.ylabel('# of towns')
plt.title("Distribution of age")
plt.show()

# %%
plt.boxplot([Bhousing.MEDV,Bhousing.LSTAT])
plt.title('Boxplot on MDEV and LSTAT')
plt.show()

# %%
plt.boxplot(Bhousing.CRIM)
plt.ylim(0,12)
plt.show()

# %%
plt.scatter(Bhousing.MEDV,Bhousing.RM,color="teal")
plt.xlabel("Median House Price")
plt.ylabel("Number of Rooms")
plt.show()

# %%
plt.scatter(Bhousing.MEDV,Bhousing.ZONE)
plt.show()

# %%
plt.scatter(Bhousing.MEDV,Bhousing.AGE,color="teal")

# %%
plt.scatter(Bhousing.MEDV,Bhousing.RAD,color="teal")

# %%
plt.scatter(Bhousing.MEDV,Bhousing.AGE,color="teal")

# %%
plt.scatter(Bhousing.MEDV,Bhousing.LSTAT,color="teal")

# %%
plt.scatter(Bhousing.MEDV,Bhousing.CRIM,color="teal")
plt.yscale('log')

# %%
plt.pie([40,60])
plt.show()

# %%
Bhousing['CHAS'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
size=[417,35]
label1=['Not close','Close']
plt.pie(size,labels=label1,autopct='%1.1f%%',startangle=90)
plt.title("Proportion of CHAS")
plt.show()

# %%
size=[200,100,50]
label1=['IS','MKT','MGMT']
plt.pie(size,labels=label1,autopct='%1.1f%%',startangle=90)
plt.title("Proportion of CHAS")
plt.show()

# %%
Weather=pd.read_csv(r"/Users/karanbhosale/Documents/Big Data Strategy/Chicago Weather.csv")

# %%
Weather
# Out:
#    Month   Temp_max   Temp_min   Temp_avg  Precipitation  Snow depth
# 0    Jan  28.580645  12.580645  20.580645       0.035000    2.354839
# 1    Feb  42.214286  25.500000  33.857143       0.159583    0.571429
# 2    Mar  49.064516  32.354839  40.709677       0.136667    0.096774
# 3    Apr  55.133333  38.933333  47.033333       0.212400    0.000000
# 4    May  72.225806  55.225806  63.725806       0.138800    0.000000
# 5    Jun  82.566667  61.866667  72.216667       0.095000    0.000000
# 6    Jul  83.516129  67.000000  75.258065       0.204545    0.000000
# 7    Aug  83.032258  65.677419  74.354839       0.085417    0.000000
# 8    Sep  75.966667  58.800000  67.383333       0.081481    0.000000
# 9    Oct  63.903226  44.161290  54.032258       0.059286    0.000000
# 10   Nov  51.666667  35.100000  43.383333       0.034400    0.033333
# 11   Dec  35.709677  22.516129  29.112903       0.093913    0.225806

# %%
plt.plot(Weather.Month,Weather.Temp_max,marker='v',color='red')
plt.plot(Weather.Month,Weather.Temp_avg,marker='o',color='blue')
plt.plot(Weather.Month,Weather.Temp_min,marker='x',color='black',linestyle="--")
plt.title("Weather in chicago (2022)")
plt.xlabel("Months")
plt.ylabel("Temp (f)")
plt.show()

# %%
fix,ax=plt.subplots()
ax.bar(Weather.Month,Weather.Precipitation)
ax.set_ylabel("Precipitation_inch")
ax.set_title("Weather chicago (2022)")
ax2=ax.twinx()
ax2.plot(Weather.Month,Weather.Temp_avg,color="red")
ax2.set_xlabel('month')
ax2.set_ylabel('Temperature (F)')
# Out:
# Text(0, 0.5, 'Temperature (F)')

# %%
Covid=pd.read_csv(r"/Users/karanbhosale/Documents/Big Data Strategy/Covid-19_month.csv")

# %%
Covid
# Out:
#    Month    Cases  Deaths
# 0      1        7       0
# 1      2       58       0
# 2      3   188411    4288
# 3      4   887343   58851
# 4      5   723578   41104
# 5      6   854080   23066
# 6      7  1918317   26336
# 7      8  1473553   29392
# 8      9   702164   14838

# %%
fix,ax=plt.subplots()
ax.bar(Covid.Month,Covid.Cases)
ax.set_ylabel("Positive_cases")
ax.set_title("Covid Trend in (2022)")
ax2=ax.twinx()
ax2.plot(Covid.Month,Covid.Deaths,color="red")
ax2.set_ylabel('Deaths')
# Out:
# Text(0, 0.5, 'Deaths')

# %%
import numpy as np
categories = ['Programming', 'Critical Thinking', 'Analytical Skills', 'Communication','Persistency','Problem Solving']
categories = [*categories, categories[0]]
My_ability = [4, 4, 5, 4, 5,10]
Others = [3,3,4,3,3,7]
RCOBA = [2,3,3,4,3,7]
My_ability = [*My_ability, My_ability[0]]
Others = [*Others, Others[0]]
RCOBA = [*RCOBA, RCOBA[0]]
label_loc = np.linspace(start=0, stop=2 * np.pi, num=len(My_ability))
plt.figure(figsize=(4, 4))
plt.subplot(polar=True)
plt.plot(label_loc, My_ability, label='My Abilities')
plt.plot(label_loc, Others, label='ISQS Average')
plt.plot(label_loc, RCOBA, label='RCOBA Average')
plt.title('My Abilities vs. Others')
lines, labels = plt.thetagrids(np.degrees(label_loc), labels=categories)
plt.legend(loc='lower right')
plt.show()

# %%
Order=pd.read_csv(r"/Users/karanbhosale/Documents/Big Data Strategy/Orders.csv")
Returns=pd.read_csv(r"/Users/karanbhosale/Documents/Big Data Strategy/Returns.csv")
People=pd.read_csv(r"/Users/karanbhosale/Documents/Big Data Strategy/People.csv")

# %%
Order_Returns_inner=Order.merge(Returns,on='Order_ID')

# %%
Order_Returns_inner.head(3)
# Out:
#    Row ID        Order_ID Order Date Ship Date     Ship Mode Customer ID  \
# 0      19  CA-2014-143336  8/27/2014  9/1/2014  Second Class    ZD-21925
# 1      20  CA-2014-143336  8/27/2014  9/1/2014  Second Class    ZD-21925
# 2      21  CA-2014-143336  8/27/2014  9/1/2014  Second Class    ZD-21925
#
#         Customer Name   Segment        Country           City  ... Region  \
# 0  Zuschuss Donatelli  Consumer  United States  San Francisco  ...   West
# 1  Zuschuss Donatelli  Consumer  United States  San Francisco  ...   West
# 2  Zuschuss Donatelli  Consumer  United States  San Francisco  ...   West
#
#         Product ID         Category Sub-Category  \
# 0  OFF-AR-10003056  Office Supplies          Art
# 1  TEC-PH-10001949       Technology       Phones
# 2  OFF-BI-10002215  Office Supplies      Binders
#
#                                   Product Name   Sales Quantity  Discount  \
# 0                                   Newell 341    8.56        2       0.0
# ...

# %%
Order_Returns_inner.shape
# Out:
# (800, 22)

# %%
Order_Returns_left=Order.merge(Returns,how='left',on='Order_ID')

# %%
Order_Returns_left.shape
# Out:
# (9994, 22)

# %%
Order_Returns_left.head(10)
# Out:
#    Row ID        Order_ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ... Region  \
# ...

# %%
Order_Returns_right=Order.merge(Returns,how='right',on='Order_ID')

# %%
Order_Returns_right.head(5)
# Out:
#    Row ID        Order_ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    6971  CA-2017-153822  9/19/2017  9/25/2017  Standard Class    AB-10105
# 1    6972  CA-2017-153822  9/19/2017  9/25/2017  Standard Class    AB-10105
# 2    6973  CA-2017-153822  9/19/2017  9/25/2017  Standard Class    AB-10105
# 3    6974  CA-2017-153822  9/19/2017  9/25/2017  Standard Class    AB-10105
# 4    5434  CA-2017-129707  4/25/2017  4/29/2017  Standard Class    LH-16750
#
#    Customer Name   Segment        Country      City  ... Region  \
# 0  Adrian Barton  Consumer  United States   Phoenix  ...   West
# 1  Adrian Barton  Consumer  United States   Phoenix  ...   West
# 2  Adrian Barton  Consumer  United States   Phoenix  ...   West
# 3  Adrian Barton  Consumer  United States   Phoenix  ...   West
# 4   Larry Hughes  Consumer  United States  Chandler  ...   West
#
#         Product ID         Category Sub-Category  \
# 0  OFF-ST-10000321  Office Supplies      Storage
# ...

# %%
Order_People_left=Order.merge(People,how='left',on='Region')

# %%
Order.head(3)
# Out:
#    Row ID        Order_ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 1       2  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 2       3  CA-2016-138688  6/12/2016   6/16/2016  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# ...

# %%
Order_People_left.head(5)
# Out:
#    Row ID        Order_ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
Order_People_left.shape
# Out:
# (9994, 22)

# %%
DF1=pd.read_csv("/Users/karanbhosale/Documents/Big Data Strategy/202303-divvy-tripdata.csv")

# %%
DF2=pd.read_csv("/Users/karanbhosale/Documents/Big Data Strategy/202304-divvy-tripdata.csv")

# %%
New_DF=pd.concat([DF1,DF2])

# %%
New_DF.shape
# Out:
# (685268, 13)
